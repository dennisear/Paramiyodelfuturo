# %%
nombre = input('Escribe tu nombre: ')
apellido = input('Escribe tu apellido: ')
edad_2022 = int(input('Digita tu edad en febrero de 2022: '))
# Out:
# Escribe tu nombre: Dennis
# Escribe tu apellido: Arango
# Digita tu edad en febrero de 2022: 18

# %%
nombre_upper = nombre.upper()
apellido_upper = apellido.upper()

# %% [markdown]
# ## CARTA PARA EL 13/02/2023

# %%
print('\033[1m'+'¡HOLA,'.rjust(40, ' '), nombre_upper, apellido_upper, 'DEL FUTURO! '.ljust(40, ' ')+'\033[0m')
print('Escribí esta carta para ti el 13 de febrero de 2022, cuando tenías', edad_2022, 'años y estabas finalizando' '\n' 'tu primera semana de tu primer semestre en ciencia de datos, en la universidad en la que siempre' '\n' 'soñaste estudiar, ¡wooooow!. Fue bastante complicado, ya que, ingresaste dos semanas después de' '\n' 'todos tus compañeros y tuviste que acelerar un poco el ritmo, pero se logró y mírate, ya pasó un' '\n' 'año, estás en tercer semestre y cada día más enamorada de tu carrera.')
print('Espero sigas trabajando como desarrolladora en esa empresa que tanto te gusta y tanto te ha brindado,' '\n' 'PD: en unos años tendrás tu propia empresa de desarrollo, ya estoy trabajando para ello y yo sé que' '\n' 'tú estás trabajando el doble, por favor ¡NO DEJES DE ESTUDIAR!, ni la carrera, ni todos aquellos' '\n' 'lenguajes de programación de los que te falta aprender.')
print('Por último, no olvides que los proyectos necesitan tiempo, que las personas necesitan tiempo, que' '\n' 'el trabajo necesita tiempo, que tú eres la que domina tu tiempo y no al revés, como muchos creen.' '\n' 'Hazte dueña de él y dale un sentido, que no pase sin contar nada, que el tiempo hable, que los' '\n' 'momentos llenen esos relojes de historias.''\n')
print('\033[1m'+'¡Nos leemos en cuatro años!'+'\033[0m')
# Out:
#                                   ¡HOLA, DENNIS ARANGO DEL FUTURO!
# Escribí esta carta para ti el 13 de febrero de 2022, cuando tenías 18 años y estabas finalizando
# tu primera semana de tu primer semestre en ciencia de datos, en la universidad en la que siempre
# soñaste estudiar, ¡wooooow!. Fue bastante complicado, ya que, ingresaste dos semanas después de
# todos tus compañeros y tuviste que acelerar un poco el ritmo, pero se logró y mírate, ya pasó un
# año, estás en tercer semestre y cada día más enamorada de tu carrera.
# Espero sigas trabajando como desarrolladora en esa empresa que tanto te gusta y tanto te ha brindado,
# PD: en unos años tendrás tu propia empresa de desarrollo, ya estoy trabajando para ello y yo sé que
# tú estás trabajando el doble, por favor ¡NO DEJES DE ESTUDIAR!, ni la carrera, ni todos aquellos
# lenguajes de programación de los que te falta aprender.
# Por último, no olvides que los proyectos necesitan tiempo, que las personas necesitan tiempo, que
# ...

# %% [markdown]
# -----

# %% [markdown]
# ## CARTA PARA EL 13/02/2027

# %%
sueldoActual = float(input('Digita tu sueldo actual: '))
# Out:
# Digita tu sueldo actual: 10000

# %%
print('\033[1m'+'¡HOLA,'.rjust(40, ' '), nombre_upper, apellido_upper, 'DEL FUTURO! '.ljust(40, ' ')+'\033[0m')
print('Esta carta la escribí para ti, cinco años atrás, cuando recién iniciabas la universidad, y...')
print('Woow, ¡Ya eres una científica de datos!'.rjust(70, ' '))
print('Realmente espero que estés disfrutando mucho lo que haces profesionalmente, que el trabajo sea' '\n' 'algo que te guste hacer y que no sufras.')
print('Académicamente esta carta se trata de contarte cuanto dinero creo que puedo ganar y para que tú' '\n' 'me cuentes la realidad, pero antes, quiero que recuerdes que NO estudiaste cuatro años por el' '\n' 'dinero, a menudo te dicen que este es lo más importante, pero yo creo que lo más importante' '\n' 'siempre será seguir tú corazón y hacer lo que te hace feliz; porque entonces te puedes esforzar' '\n' 'más, puedes poner el máximo empeño y tarde o temprano la vida te va a recompensar.')
print('Ahora sí, cuéntame, ¿Cuánto ganas?: $', sueldoActual, '¡Increíble! Yo por mi parte, te cuento que' '\n' 'acabé de revisar en Google y aproximadamente un científico de datos gana un sueldo mínimo anual' '\n' 'de $48.772. 800  y bueno, ¿por qué no?, haces una labor muy importante, ya estoy luchando para' '\n' 'hacerlo realidad.')
print('Espero que nunca olvides cuál es tu pasión, que no se te olvide quién eres. No dejes que nadie te' '\n' 'haga cambiar esa esencia, que te haga dudar de ti misma, de tus ideas, de tus capacidades.' '\n' 'Algún día llegará eso que tanto esperabas. ''\n')
print('\033[1m'+'Te quiere,'+'\033[0m')
print('Tú yo de 18 años.')
# Out:
#                                   ¡HOLA, DENNIS ARANGO DEL FUTURO!
# Esta carta la escribí para ti, cinco años atrás, cuando recién iniciabas la universidad, y...
#                                Woow, ¡Ya eres una científica de datos!
# Realmente espero que estés disfrutando mucho lo que haces profesionalmente, que el trabajo sea
# algo que te guste hacer y que no sufras.
# Académicamente esta carta se trata de contarte cuanto dinero creo que puedo ganar y para que tú
# me cuentes la realidad, pero antes, quiero que recuerdes que NO estudiaste cuatro años por el
# dinero, a menudo te dicen que este es lo más importante, pero yo creo que lo más importante
# siempre será seguir tú corazón y hacer lo que te hace feliz; porque entonces te puedes esforzar
# más, puedes poner el máximo empeño y tarde o temprano la vida te va a recompensar.
# Ahora sí, cuéntame, ¿Cuánto ganas?: $ 10000.0 ¡Increíble! Yo por mi parte, te cuento que
# ...
